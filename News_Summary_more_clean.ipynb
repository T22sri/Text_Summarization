# %%
# import libraries
import json
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Importing the dataset
df_1 = pd.read_csv("/content/gdrive/MyDrive/612_DeepLearning/Final_Project/news_summary/news_summary.csv", encoding='iso-8859-1')
df_2 = pd.read_csv("/content/gdrive/MyDrive/612_DeepLearning/Final_Project/news_summary/news_summary_more.csv", encoding='iso-8859-1')

# %%
print(df_1.shape)
print(df_2.shape)
# Out:
# (4514, 6)
# (98401, 2)

# %%
df_1.head()
# Out:
#                author                  date  \
# 0        Chhavi Tyagi  03 Aug 2017,Thursday
# 1         Daisy Mowke  03 Aug 2017,Thursday
# 2      Arshiya Chopra  03 Aug 2017,Thursday
# 3       Sumedha Sehra  03 Aug 2017,Thursday
# 4  Aarushi Maheshwari  03 Aug 2017,Thursday
#
#                                            headlines  \
# 0  Daman & Diu revokes mandatory Rakshabandhan in...
# 1  Malaika slams user who trolled her for 'divorc...
# 2  'Virgin' now corrected to 'Unmarried' in IGIMS...
# 3  Aaj aapne pakad liya: LeT man Dujana before be...
# 4  Hotel staff to get training to spot signs of s...
#
#                                            read_more  \
# 0  http://www.hindustantimes.com/india-news/raksh...
# 1  http://www.hindustantimes.com/bollywood/malaik...
# 2  http://www.hindustantimes.com/patna/bihar-igim...
# 3  http://indiatoday.intoday.in/story/abu-dujana-...
# 4  http://indiatoday.intoday.in/story/sex-traffic...
#
# ...

# %%
df_2.head()
# Out:
#                                            headlines  \
# 0  upGrad learner switches to career in ML & Al w...
# 1  Delhi techie wins free food from Swiggy for on...
# 2  New Zealand end Rohit Sharma-led India's 12-ma...
# 3  Aegon life iTerm insurance plan helps customer...
# 4  Have known Hirani for yrs, what if MeToo claim...
#
#                                                 text
# 0  Saurav Kant, an alumnus of upGrad and IIIT-B's...
# 1  Kunal Shah's credit card bill payment platform...
# 2  New Zealand defeated India by 8 wickets in the...
# 3  With Aegon Life iTerm Insurance plan, customer...
# 4  Speaking about the sexual harassment allegatio...

# %%
df_1_columns = df_1.columns.tolist()
df_1_columns.remove('headlines')
df_1_columns.remove('text')
df_1.drop(df_1_columns, axis='columns', inplace=True)

df = pd.concat([df_1, df_2], axis='rows')
del df_1, df_2

# Shuffling the df
df = df.sample(frac=1).reset_index(drop=True)

print(f'Dataset size: {len(df)}')
df.sample(5)
# Out:
# Dataset size: 102915
#                                                headlines  \
# 22381  PNB shares fall 6% after posting biggest loss ...
# 65761  Gerard Pique plans a World Cup-like tournament...
# 41527     Congress entrapped in Blue Whale game: PM Modi
# 24339  Flipkart, Amazon ask govt to extend FDI policy...
# 13076  Doctor opens fire at New York hospital, kills ...
#
#                                                     text
# 22381  Shares of fraud-hit PNB fell 6.1% on Tuesday a...
# 65761  Barcelona's Spanish defender Gerard Pique is p...
# 41527  PM Narendra Modi on Monday said that Congress ...
# 24339  E-commerce platforms Flipkart and Amazon have ...
# 13076  A doctor armed with a rifle killed a female do...

# %%
# copy article and title columns
data = df[['headlines', 'text']]
print(data)
# Out:
#                                                 headlines  \
# 0       Former IPS officer Sanjiv Bhatt's bail plea re...
# 1       SC rejects PIL to declare Indus Treaty as unco...
# 2       Should print expiry date on big currency notes...
# 3             Mukesh Ambani becomes Asia's richest person
# 4       PAN cards not linked to Aadhaar by July 1 won'...
# ...                                                   ...
# 102910  Hyundai brings to you the 'Biggest Car Bonanza...
# 102911  Russia funded investments in Twitter, FB: Para...
# 102912  Trump Foundation to shut down amid corruption ...
# 102913  Sad I didn't get opportunity to defend World C...
# 102914  Same-sex marriage threatens religious freedom:...
#
#                                                      text
# 0       A Gujarat court on Friday rejected a bail appl...
# 1       The Supreme Court on Monday dismissed a PIL se...
# 2       Telugu Desam Party (TDP) MP Jayadev Galla sugg...
# ...

# %%
# print sample data

print(data['headlines'][:10])
# Out:
# 0    Daman & Diu revokes mandatory Rakshabandhan in...
# 1    Malaika slams user who trolled her for 'divorc...
# 2    'Virgin' now corrected to 'Unmarried' in IGIMS...
# 3    Aaj aapne pakad liya: LeT man Dujana before be...
# 4    Hotel staff to get training to spot signs of s...
# 5    Man found dead at Delhi police station, kin al...
# 6    Delhi HC reduces aid for 'negligent' accident ...
# 7    60-yr-old lynched over rumours she was cutting...
# 8    Chopper flying critically low led to 2015 Bomb...
# 9     Congress opens 'State Bank of Tomato' in Lucknow
# Name: headlines, dtype: object

# %%
# rename few column names
data.rename(columns = {'headlines':'summary'}, inplace = True)

# After renaming the columns
print("\nAfter modifying column names:\n", data.columns)
# Out:
# After modifying column names:
#  Index(['summary', 'text'], dtype='object')

# %%
data.sample(5)
# Out:
#                                                  summary  \
# 26642  Newly-wed bride shot dead by armed robbers on ...
# 12077  Melania appears to refuse to hold Trumps hand ...
# 78008  Google disallows changing domain to search dif...
# 45252  Rape cases against Kerala priests disturbing, ...
# 34584  10 of a family dead after SUV collides with tr...
#
#                                                     text
# 26642  A newly-wed bride returning home with a weddin...
# 12077  A video which purportedly shows US First Lady ...
# 78008  Technology giant Google has announced that the...
# 45252  While hearing a rape case against a priest in ...
# 34584  Ten mthembers of a family died while four othe...

# %% [markdown]
# 2. Cleaning

# %%
import re
from nltk.corpus import stopwords
import string

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
pip install -q contractions==0.0.48
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 4.7 MB/s eta 0:00:00

# %%
from contractions import contractions_dict

for key, value in list(contractions_dict.items())[:10]:
    print(f'{key} == {value}')
# Out:
# I'm == I am
# I'm'a == I am about to
# I'm'o == I am going to
# I've == I have
# I'll == I will
# I'll've == I will have
# I'd == I would
# I'd've == I would have
# Whatcha == What are you
# amn't == am not

# %%
# Remove stopwords from text
def rm_stopwords_from_text(text):
    _stopwords = stopwords.words('english')
    text = text.split()
    word_list = [word for word in text if word not in _stopwords]
    return ' '.join(word_list)

# %%
# Remove puncuation from word
def rm_punc_from_word(word):
    clean_alphabet_list = [
        alphabet for alphabet in word if alphabet not in string.punctuation
    ]
    return ''.join(clean_alphabet_list)

# Remove puncuation from text
def rm_punc_from_text(text):
    clean_word_list = [rm_punc_from_word(word) for word in text]
    return ''.join(clean_word_list)

# %%
# function to expand contractions
def expand_contractions(text, contraction_map=contractions_dict):
    # Using regex for getting all contracted words
    contractions_keys = '|'.join(contraction_map.keys())
    contractions_pattern = re.compile(f'({contractions_keys})', flags=re.DOTALL)

    def expand_match(contraction):
        # Getting entire matched sub-string
        match = contraction.group(0)
        expanded_contraction = contraction_map.get(match)
        if not expand_contractions:
            print(match)
            return match
        return expanded_contraction

    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text

# %%
def clean_text(text):
    '''Clean text by removing unnecessary characters and altering the format of words.'''

    text = text.lower()
    text = rm_stopwords_from_text(text)
    text = rm_punc_from_text(text)
    # expand contractions
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"it's", "it is", text)
    text = re.sub(r"that's", "that is", text)
    text = re.sub(r"what's", "that is", text)
    text = re.sub(r"where's", "where is", text)
    text = re.sub(r"how's", "how is", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"can't", "cannot", text)
    text = re.sub(r"n't", " not", text)
    text = re.sub(r"n'", "ng", text)
    text = re.sub(r"'bout", "about", text)
    text = re.sub(r"'til", "until", text)
    text = re.sub(r"[-()\"#/@;:<>{}`+=~''‘’“”|—.!?,]", "", text)

    return text

# %%
# apply expand contractions to text and summary
data.summary = data.summary.apply(expand_contractions)
data.text = data.text.apply(expand_contractions)
data.sample(5)
# Out:
#                                                  summary  \
# 50839  Woman spends Ã¢ÂÂ¹26 lakh on surgeries to loo...
# 132    Somali pirates hijack Indian cargo ship with 1...
# 57302  Google stopped staff from discussing diversity...
# 81737  Director stalked me, talked about love and sex...
# 73259  Jharkhand man cycles 600 km to find missing wi...
#
#                                                     text
# 50839  A 34-year-old American woman has spent $40,000...
# 132    Indian cargo ship Al Kaushar, which was on its...
# 57302  Googles former Security Engineer Cory Altheide...
# 81737  Actress Swara Bhasker, while speaking about fa...
# 73259  A 42-year-old labourer from Jharkhand cycled 6...

# %%
# apply text pre-processing function and store cleaned text in new column
data["clean_summary"] = data["summary"].apply(lambda x: clean_text(x))
data["clean_text"] = data["text"].apply(lambda x: clean_text(x))
data.head()
# Out:
#                                              summary  \
# 0  Former IPS officer Sanjiv Bhatts bail plea rej...
# 1  SC rejects PIL to are Indus Treaty as unconsti...
# 2  Should print expiry date on big currency notes...
# 3         Mukesh Ambani becomes Asias richest person
# 4  PAN cards not linked to Aadhaar by July 1 will...
#
#                                                 text  \
# 0  A Gujarat court on Friday rejected a bail appl...
# 1  The Suprtheme Court on Monday dismissed a PIL ...
# 2  Telugu Desam Party (TDP) MP Jayadev Galla sugg...
# 3  Reliance Industries Chairman Mukesh Ambani has...
# 4  The Income Tax department has clarified that P...
#
#                                        clean_summary  \
# 0  former ips officer sanjiv bhatts bail plea rej...
# 1       sc rejects pil indus treaty unconstitutional
# 2  print expiry date big currency notes lok sabha mp
# 3         mukesh ambani becomes asias richest person
# ...

# %%
print(data['clean_text'][:10])
print(data['clean_summary'][:10])
# Out:
# 0    gujarat court friday rejected bail application...
# 1    suprtheme court monday dismissed pil seeking i...
# 2    telugu desam party tdp mp jayadev galla sugges...
# 3    reliance industries chairman mukesh ambani bec...
# 4    income tax department clarified permanent acco...
# 5    french open 2017 final rafael nadal stan wawri...
# 6    talking rape cases 8monthold girl india 7yearo...
# 7    bombay high court struck nineyearold case arti...
# 8    canadabased company dbrand makes personalised ...
# 9    dr br ambedkars statue defaced red paint tamil...
# Name: clean_text, dtype: object
# 0    former ips officer sanjiv bhatts bail plea rej...
# 1         sc rejects pil indus treaty unconstitutional
# 2    print expiry date big currency notes lok sabha mp
# 3           mukesh ambani becomes asias richest person
# 4              pan cards linked aadhaar july 1 invalid
# 5               ball play 22 minutes french open final
# ...

# %%
# saving the cleaned data
data.to_csv('/content/gdrive/MyDrive/612_DeepLearning/Final_Project/data/cleaned_data_news_summary_more.csv')

# %% [markdown]
# Add start and end tokens for summary(headlines)

# %%
# load the cleaned data

data = pd.read_csv('/content/gdrive/MyDrive/612_DeepLearning/Final_Project/data/cleaned_data_news_summary_more.csv')

# %%
data.columns
print(data.dtypes)
# Out:
# Unnamed: 0.1      int64
# Unnamed: 0        int64
# summary          object
# text             object
# clean_summary    object
# clean_text       object
# dtype: object
